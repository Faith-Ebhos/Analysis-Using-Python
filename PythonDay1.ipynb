# %% [markdown]
# #Python is my favourite
# ##python is good
# ### i love python

# %%
# !python --version
# Out:
# Python 3.11.12

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
from  google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-b3fc74cffcda> in <cell line: 0>()
#       1 from  google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     277             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     278         )
# --> 279       raise ValueError('mount failed' + extra_reason)
# ...

# %%
print("3.14"*2)
# Out:
# 3.143.14

# %%
print(3.14*2)
# Out:
# 6.28

# %%
print(len("3.14"))
# Out:
# 4

# %%
print("hello\bworld")
# Out:
# world

# %%
print("I am",32,"years old",True)
# Out:
# I am 32 years old True

# %%
print("The itsy bitsy spider","climed up","the water sprout")
# Out:
# The itsy bitsy spider climed up the water sprout

# %%
print("The itsy bitsy spider"+"climed up"+"the water sprout")
# Out:
# The itsy bitsy spiderclimed upthe water sprout

# %%
print(2,3)
# Out:
# 2 3

# %%
print(2+3)
# Out:
# 5

# %%
print("2"+"3")
# Out:
# 23

# %%
print(13 +5)
print(13 -5)
print(13 /5)
print(13 *5)
print(13 %5)
print(13//5)
# Out:
# 18
# 8
# 2.6
# 65
# 3
# 2

# %%
print(4**3)
# Out:
# 64

# %%
print(math.sqrt(100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-5492a36672c1> in <cell line: 0>()
# ----> 1 print(math.sqrt(100))
#
# NameError: name 'math' is not defined

# %%
print(pow(100,0.5))
# Out:
# 10.0

# %%
import math

# %%
math.sqrt(64)
# Out:
# 8.0

# %%
# This code will import the math library

# %%
# !pip list
# show list of libraries
# Out:
# Package                               Version
# ------------------------------------- -------------------
# absl-py                               1.4.0
# accelerate                            1.7.0
# aiohappyeyeballs                      2.6.1
# aiohttp                               3.11.15
# aiosignal                             1.3.2
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.7
# ale-py                                0.11.0
# altair                                5.5.0
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.9.0
# argon2-cffi                           23.1.0
# argon2-cffi-bindings                  21.2.0
# array_record                          0.7.2
# arviz                                 0.21.0
# astropy                               7.1.0
# ...

# %%
name="Solar system"
print(name)
# Out:
# Solar system

# %%
name=solar
print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-325749afdb52> in <cell line: 0>()
# ----> 1 name=solar
#       2 print(name)
#
# NameError: name 'solar' is not defined

# %%
condition=
print(condition)
# Out:
#   File "<ipython-input-42-6b5dd46fa035>", line 1
#     condition=
#                ^
# SyntaxError: invalid syntax

# %%
my_age=33
your_age=30
my_age=your_age
print(my_age)
# Out:
# 30

# %%
myName="Faith"
print(myName)
print(type(myName))
print(len(myName))
# Out:
# Faith
# <class 'str'>
# 5

# %%
print("Please enter your name:")
myname = input()
print(f"Hi, {myname}. Nice to meet you.")
# Out:
# Please enter your name:
# Faith
# Hi, Faith. Nice to meet you.

# %%
myname = input()
print(f"Hi, {myname}. Nice to meet you.")
# Out:
# James
# Hi, James. Nice to meet you.

# %%
print("Please enter your name:")
myage = input("Please enter your age")
print(f"I am, {myage}. years old.")
# Out:
# Please enter your name:
# Please enter your age23
# I am, 23. years old.

# %%
num1=input("Enter first value")
num2=input("enter second value")
print(int(num1+num2))
print(int(num1))
print(int(num2)*2)
# Out:
# Enter first value1
# enter second value2
# 12
# 1
# 4

# %%
print("tell me time in hours and i will calculate in seconds")
time_hour = input("how many hours?")
print(f"Time in seconds is int(time_hour)*60*60")

# %%
print("Tell me time in hours and I will calculate in seconds")
time_hour = input("how many hours? ")

print(f"Time in seconds is {float(time_hour) * 60 * 60}")
# float function can convert decimal
# Out:
# Tell me time in hours and I will calculate in seconds
# how many hours? 3
# Time in seconds is 10800.0

# %%
print(my_age)
 # keywords  stored in memory
# Out:
# 30

# %%
#both int or float are used to convert string to numeric
number1 =input("enter a number")
print(float(number1)*2)
# Out:
# enter a number20.4
# 40.8

# %%
number1=input("enter the first number")
number2=input("enter the second number")
print(float(number1)*float(number2))
print(float(number1)+float(number2))
print(float(number1)-float(number2))
print(float(number1)/float(number2))
# Out:
# enter the first number6
# enter the second number3
# 18.0
# 9.0
# 3.0
# 2.0

# %%
number1 = float(input("Enter your first number: "))
number2 = float(input("Enter your second number: "))

print(f"Answers: {number1 + number2}, {number1 - number2}, {number1 * number2}, {number1 / number2}")
# Out:
# Enter your first number: 5
# Enter your second number: 6
# Answers: 11.0, -1.0, 30.0, 0.8333333333333334
